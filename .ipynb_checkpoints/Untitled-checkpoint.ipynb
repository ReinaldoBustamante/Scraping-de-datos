# %% [markdown]
# # Caso de estudio "YAPO"

# %% [markdown]
# Queremos implementar una base de datos que almacena anuncios Yapo de la Región de Los Ríos. Nuestra base de datos deberá seguir el modelo Entidad-Relación siguiente:

# %% [markdown]
# <img src="diagrama.png">

# %% [markdown]
# ## Pregunta 1: Proponer un modelo relacional derivado del modelo E-R

# %% [markdown]
# <img src="modelo.jpeg">

# %% [markdown]
# ### Pregunta 2: Proponer un modelo de base de datos "Documentos" (Mongo) derivado del modelo E-R

# %% [markdown]
# <img src="documento.jpeg">

# %% [markdown]
# ### Pregunta 3: Implementar un script Python para crear la estructura de la base de datos "Yapo-LosRios" (NB: pueden elegir el SGBD que desea)

# %%
import mysql.connector
db_connection = mysql.connector.connect(user="root",host="localhost",password="spawn1997")
cursor = db_connection.cursor()

# %%
cursor.execute("DROP DATABASE Yapo;") #elimina la base de datos si es que ya existe.

# %%
cursor.execute("CREATE DATABASE Yapo;")
cursor.execute("USE Yapo")

#tabla vendedor
cursor.execute("CREATE TABLE vendedor ("+
               "id_vendedor VARCHAR(130) PRIMARY KEY, nombre VARCHAR(100), ciudad VARCHAR(30), codigo_region VARCHAR(7), "+
               "nombre_region VARCHAR(30), "+
               "fecha_inscripcion DATE)")

#tabla anuncio
cursor.execute("CREATE TABLE anuncio (url VARCHAR(300) PRIMARY KEY, "+
               "titulo VARCHAR(200), descripcion MEDIUMTEXT, precio INT, moneda VARCHAR(2), fecha_publicacion DATE, categoria VARCHAR(50), "
               +"id_vendedor VARCHAR(130), FOREIGN KEY (id_vendedor) REFERENCES vendedor(id_vendedor))")

# %% [markdown]
# ### Pregunta 4: Implementar un script Python para llenar la base de datos "Yapo-LosRios" escrapeando algunos datos de Yapo.cl

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /home/spun/miniconda3/lib/python3.7/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /home/spun/miniconda3/lib/python3.7/site-packages (from selenium) (1.25.8)

# %%
from urllib.request import urlopen as uReq
import urllib.request

from bs4 import BeautifulSoup as soup
from selenium import webdriver
import time

# %% [markdown]
# con la libreria Selenium, abriremos un navegador Chrome, en la pagina de los anuncios de Yapo en la region de los Rios

# %%
#requisito installar sudo apt install chromium-chromedriver

# %%
browser = webdriver.Chrome()
myUrl = 'https://www.yapo.cl/chile/todos_los_avisos?ca=12_s&l=0'
browser.get(myUrl)

# %% [markdown]
# Con la libreria BeautifulSoup, realizamos un scrapping del codigo HTML para recuperar el enlace de la "ultima pagina"

# %%
pageSoup = soup(browser.page_source, 'html.parser')

pages = pageSoup.find('span', {'class', 'nohistory FloatRight'}).a['href']

# %%
pages
# Out:
# 'https://www.yapo.cl/chile?ca=12_s&o=28212'

# %% [markdown]
# el parametro 'o=numero' de la URL corresponde al numero de pagina en la lista de anuncios

# %%
index = pages.rfind('=')
print(index)
lastPage = int(pages[index+1:])
print(lastPage)
root_pages = pages[:index+1]
print(root_pages)
# Out:
# 35
# 28212
# https://www.yapo.cl/chile?ca=12_s&o=

# %% [markdown]
# se empieza a iterar para scrapear datos

# %%
import datetime

def convert_date(yapo_date):
    month=yapo_date.split(" ")[0]
    year=yapo_date.split(" ")[1]
    
    convert = {'Enero' : 1,
            'Febrero' : 2,
            'Marzo' : 3,
            'Abril' : 4,
            'Mayo' : 5,
            'Junio' : 6,
            'Julio' : 7,
            'Agosto' : 8,
            'Septiembre' : 9, 
            'Octubre' : 10,
            'Noviembre' : 11,
            'Diciembre' : 12
           }
    
    
    new_date=datetime.date(int(year), convert[month], 1) 

    return new_date

print(convert_date("Febrero 2020"))
# Out:
# 2020-02-01

# %%
for i in range(lastPage):
    
    #recuperarmos la URL de la pagina corriente
    url = root_pages + str(i+1)
    
    #con Selenium, vamos en navegar en esta página
    browser.get(url)
    
    #empezamos el scrapping de la pagina corriente
    pageSoup = soup(browser.page_source, 'html.parser')
    
    #recuperamos todos los tags HTML que corresponden a la lista de anuncios en esta pagina
    links = pageSoup.findAll('td', {'class' : 'thumbs_subject'})
    
    #empezamos a iterar sobre cada anuncio
    for link in links:
        
        #todos los datos que necesitamos encontrar
        url, titulo, descripcion, precio, fecha_publicacion, categoria="","","",None,"", ""
        nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion="","","","",""
        
        #Navegamos hacia la pagina del anuncio
        url=link.find('a',{'class':'title'})['href']
        #print(url)
        browser.get(link.find('a',{'class':'title'})['href'])

        #RECUPERAMOS LA FECHA DE PUBLICACION DEL ANUNCIO          
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('time')):
            datetime_raw = pageSoup.find('time').attrs['datetime']
            date_publication_raw=datetime_raw.split("T")[0]
            date_publication_raw=  date_publication_raw.split("-")
            
            date_publication=datetime.date(int(date_publication_raw[0]), int(date_publication_raw[1]),
                                           int(date_publication_raw[2]))
            #print("datetime:")
            #print(date_publication)
        
        #RECUPERAMOS EL TITULO DEL ANUNCIO           
        pageSoup = soup(browser.page_source, 'html.parser')
        if(pageSoup.find('h1', {"id" : "da_subject"})):
            titulo = pageSoup.find('h1', {"id" : "da_subject"}).text.strip()
            #print(titulo)
            
        #RECUPERAMOS LA DESCRIPCION DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "description"})):
            try:
                descripcion = pageSoup.find('div', {"class" : "description"}).text.split(' ', 1)[1].strip().replace(u'\n', u' ')
            except:
                continue
                
        #RECUPERAMOS EL PRECIO DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "price text-right"})):
            precio_raw = pageSoup.find('div', {"class" : "price text-right"}).text.strip().replace(u'\n', u' ').replace(u'\t', u'')
            precio_raw = precio_raw.split(" ")
            moneda = precio_raw[0]
            precio = precio_raw[1].split(",")[0].replace(u'.', u'')
            #print("precio:"+precio)
            
        #RECUPERAMOS LA CATEGORIA DEL ANUNCIO
        if(pageSoup.find('div', {"class" : "breadcrumbs"})):
            categoria = pageSoup.find('div', {"class" : "breadcrumbs"}).find('a', {"id" : "breadcrumb_category"}).find('strong').text.strip().replace(u'\n', u' ')
            #print(categoria)
            
        
        #RECUPERAMOS EL NOMBRE DEL VENDEDOR, SU FECHA DE INSCRIPCION Y SU LOCALIDAD
        if(pageSoup.find('aside', {"class" : "sidebar-right"})):
            aside = pageSoup.find('aside', {"class" : "sidebar-right"})
    
            #print(aside.find('seller-info'))
            
            #NOMBRE
            if(aside.find('seller-info')!=None):
                nombre=aside.find('seller-info').attrs['username']
            
                #FECHA DE INSCRIPCION
                fecha_inscripcion_raw=aside.find('seller-info').attrs['seniority']
                try:
                    fecha_inscripcion_raw=fecha_inscripcion_raw[len("En Yapo desde "):]
                    fecha_inscripcion=convert_date(fecha_inscripcion_raw)
                    #print(fecha_inscripcion)
                except:
                    fecha_inscripcion=None
                    continue
                
                #LOCALIDAD
                localidad_raw=aside.find('seller-info').attrs['region']
            
                #print(localidad_raw)
            
                region_raw=localidad_raw.split(",")[0]
                ciudad_raw=localidad_raw.split(",")[1]
            
                codigo_region=region_raw.split(" ")[0]
                nombre_region=region_raw[len(codigo_region)+1:]
                ciudad=ciudad_raw[1:]
                
        # LLENAMOS LA BASE DE DATOS: TABLA VENDEDOR
        
        try:
            sql = "INSERT INTO vendedor (id_vendedor,nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion) VALUES (%s,%s, %s, %s,%s,%s)"
            val = (nombre+"_"+codigo_region+"_"+ciudad,nombre, ciudad, codigo_region, nombre_region, fecha_inscripcion)
            cursor.execute(sql, val)
        except Exception as e1:
            print(e1)
            #continue
        
        # LLENAMOS LA BASE DE DATOS: TABLA ANUNCIO
        try:
            sql = "INSERT INTO anuncio (url, titulo, descripcion, precio, moneda, fecha_publicacion, categoria, id_vendedor) VALUES (%s, %s, %s,%s, %s, %s, %s, %s)"
            val = (url, titulo, descripcion, int(precio), moneda, date_publication, categoria, nombre+"_"+codigo_region+"_"+ciudad)
            cursor.execute(sql, val)
        except Exception as e2:
            continue
        
        cursor.execute("COMMIT")
# Out:
# 1062 (23000): Duplicate entry 'Tattersall Remates_Región_Estación Central' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Esteban_XVI_Chillán' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Sofia Alegria_V_Quilpué' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'inmobiliaria_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'cristian_Región_Lampa' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'patricio_Región_Cerrillos' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Hernan Frío Avendaño_V_Viña del Mar' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Hernan Frío Avendaño_V_Viña del Mar' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Hernan Frío Avendaño_V_Viña del Mar' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Dagoberto_V_Villa Alemana' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'David Alfredo Pavez_Región_Santiago' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Dagoberto_V_Villa Alemana' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'yolanda_VI_Rancagua' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Super Práctico_XIV_Valdivia' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'cynthia carrillo_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'eduardo_Región_Tiltil' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Mit_V_Quilpué' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'luiseduardofigueroaanabalon69_IX_Temuco' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'agustin_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Fabian Carrillo_Región_La Florida' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Fabian Carrillo_Región_La Florida' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'cristian_Región_Lampa' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'cristian_Región_Lampa' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'eduardo_Región_Tiltil' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Valentina_VII_Talca' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Carolina Araya Gutiérrez_Región_La Reina' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'eduardo_Región_Tiltil' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'cristian_Región_Lampa' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Carolina Araya Gutiérrez_Región_La Reina' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'kasandra_XII_Punta Arenas' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Yivana_Región_Vitacura' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'yolanda_VI_Rancagua' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Super Práctico_XIV_Valdivia' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Ignacio Rodolfo Zaror Toledo_VII_Talca' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Cristian _XVI_Chillán' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'coke_Región_San Bernardo' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'alex emilio bastias viveros_IX_Temuco' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Ignacio_IX_Vilcún' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Valentina_VII_Talca' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Fabian Carrillo_Región_La Florida' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Carmen_IX_Temuco' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Arcadio Abner Carrera Delgado_XI_Coyhaique' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Juan Carlos Ferreira Gomes _Región_Quinta Normal' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'cynthia carrillo_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Mario Antonio _Región_Puente Alto' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Abraham Leandro Mejias Arteaga_Región_Santiago' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Stephanie _VIII_Concepción' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Flavio Arriaza Silva_Región_San Miguel' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Yair _VIII_Los Ángeles' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'eduardo_Región_Tiltil' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Mit_V_Quilpué' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Margaret _IV_Canela' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'luiseduardofigueroaanabalon69_IX_Temuco' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Ángela Licas_I_Iquique' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Jamira polett reyes López _Región_Puente Alto' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Alejandra _V_Quilpué' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Iván_IX_Temuco' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'darling espinoza _VIII_Talcahuano' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'AnisCartujo_Región_Quinta Normal' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Miguel Antonio Berrueta_Región_Melipilla' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Reitz Propiedades_V_Zapallar' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Sara Alvarado_Región_Las Condes' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Dyar Panguipulli_XIV_Panguipulli' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'javier_IV_Coquimbo' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Inmobiliaria C & A LTDA_IX_Temuco' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'idr chile spa_IV_Los Vilos' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Berni Ap_Región_Santiago' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Daniel Santibañez_XVI_Bulnes' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'jose_Región_El Bosque' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Macarena Mellado Poblete_VIII_San Pedro de la Paz' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'oscar mauricio betancourt_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Gaaaaa_X_Puerto Montt' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'juan carlos collao_Región_Providencia' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'sebastian_Región_Providencia' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'pasto en rollo_Región_Lampa' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Diana_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Desarmaduria Mocadi_I_Alto Hospicio' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'marco quinteros sanchez_Región_Quinta Normal' for key 'PRIMARY'
# 1062 (23000): Duplicate entry '
for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'sebastian ahumada_Región_Estación Central' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Benjamin Zavala_Región_Calera de Tango' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Barbara Martinez Fuentes_Región_Lampa' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Tienda Syvbike_Región_Santiago' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'matjano_Región_Lo Barnechea' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'moragam_VIII_San Pedro de la Paz' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Rodrigo  Ibaceta_V_Quilpué' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'franciscopizarro32_IV_La Serena' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Esteban_XVI_Chillán' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Karen Fernandez Miranda_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'manuel martinez_Región_Cerrillos' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Carolina Santiago_Región_Maipú' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Sra.Oriana_II_Calama' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'jose luis castro sosa_II_Antofagasta' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'jose niño_IV_Coquimbo' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'catalina saldias nuñez_VI_Rancagua' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Francisco Jofre_Región_Estación Central' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Mauricio Ramírez_Región_Huechuraba' for key 'PRIMARY'
# 1062 (23000): Duplicate entry 'Roberto Caro_VI_Rancagua' for key 'PRIMARY'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-3ffeebf1b71a> in <module>
#      38
#      39         #RECUPERAMOS EL TITULO DEL ANUNCIO
# ---> 40         pageSoup = soup(browser.page_source, 'html.parser')
#      41         if(pageSoup.find('h1', {"id" : "da_subject"})):
#      42             titulo = pageSoup.find('h1', {"id" : "da_subject"}).text.strip()
#
# ~/miniconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~/miniconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/miniconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/miniconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      74         if method in self._encode_url_methods:
#      75             return self.request_encode_url(
# ---> 76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#      78         else:
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/miniconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/miniconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/miniconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/miniconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Pregunta 5: Implementar un script Python para resolver las consultas siguientes:

# %%
#!pip install pyshp
#!pip install seaborn
#!conda install pandas
#!conda install numpy
#!conda install matplotlib

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from pandas import DataFrame
import pandas as pd

sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(12,6))

# %%javascript
IPython.OutputArea.auto_scroll_threshold = 9999;
# Out:
# UsageError: Line magic function `%%javascript` not found.

# %%
#%lsmagic

# %%
import mysql.connector 

db_connection = mysql.connector.connect(user="root",host="localhost",password="spawn1997")
cursor = db_connection.cursor()

cursor.execute("use Yapo")

# %% [markdown]
# * **¿Cual es el precio promedio de los anuncios por categoria?**

# %%
sql = "SELECT categoria, avg(precio) FROM anuncio WHERE moneda=\"$\" GROUP BY categoria ORDER BY avg(precio) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                     categoria    avg(precio)
# 0                             Vendo - Terreno  90801588.1333
# 1                                Vendo - Casa  89666666.6667
# 2                        Vendo - Departamento  82097500.0000
# 3                  Buses, camiones y furgones  14181290.3871
# 4                             Otros vehículos  11980000.0000
# 5              Vendo - Comercial e industrial   7500000.0000
# 6                     Autos, camionetas y 4x4   6220769.2308
# 7          Accesorios y piezas para vehículos   3136713.0000
# 8                                       Motos   1563636.3636
# 9                             Otros productos   1062207.7778
# 10          Arriendo - Comercial e industrial    826666.6667
# 11        Negocios, maquinaria y construcción    774479.0769
# 12                          Ofertas de empleo    584357.1429
# 13                    Arriendo - Departamento    346999.9750
# 14                            Arriendo - Casa    290246.8889
# 15                  Animales y sus accesorios    221250.0000
# 16          Celulares, teléfonos y accesorios    165600.0000
# 17            Deportes, gimnasia y accesorios    139800.0000
# 18          Bicicletas, ciclismo y accesorios    132000.0000
# 19  Arriendo - Estacionamiento, bodega u otro    130000.0000
# 20                                    Muebles    124595.9615
# 21                  Computadores y accesorios    116138.8889
# 22              Audio, TV, video y fotografía    102332.3810
# 23                           Arriendo - Pieza     99437.5000
# 24         Consolas, videojuegos y accesorios     89578.4211
# 25                          Electrodomésticos     86800.0000
# 26                                  Servicios     85315.7895
# 27        Instrumentos musicales y accesorios     65428.5714
# 28           Arte, antigüedades y colecciones     58550.0000
# 29                          Hobbies y outdoor     57515.3846
# 30          Jardín, herramientas y exteriores     43762.5000
# 31             Bolsos, bisutería y accesorios     42841.9355
# 32                                   Juguetes     41722.2222
# 33              Coches y artículos infantiles     32111.1111
# 34                                    Calzado     28374.1667
# 35            Música y películas (DVDs, etc.)     26181.8182
# 36                           Moda y vestuario     24652.3636
# 37                  Otros artículos del hogar     24186.8750
# 38                            Salud y belleza     21740.3030
# 39                          Libros y revistas     14977.8571
# 40              Vestuario futura mamá y niños     10306.4516

# %% [markdown]
# * **¿Cual es el numero de anuncios por vendedor?**

# %%
sql = "SELECT id_vendedor, nombre, count(*) as_nb_anuncios FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor, nombre ORDER BY count(*) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                           id_vendedor       nombre  as_nb_anuncios
# 0      agustin_Región_Calera de Tango      agustin              24
# 1               cristian_Región_Lampa     cristian              14
# 2    moragam_VIII_San Pedro de la Paz      moragam              13
# 3                Diana_II_Antofagasta        Diana              12
# 4                       Mit_V_Quilpué          Mit              12
# ..                                ...          ...             ...
# 459                 Diego_IV_Coquimbo        Diego               1
# 460        Juan Carlos_V_Viña del Mar  Juan Carlos               1
# 461               Margot_Región_Ñuñoa       Margot               1
# 462            Angel_Región_Melipilla        Angel               1
# 463                 Claudio_V_Quilpué      Claudio               1
#
# [464 rows x 3 columns]

# %% [markdown]
# * **Insertar una columna "Perfil" de la tabla Vendedor. Los Vendedores que publicaron mas de 5 anuncios en el ultimo dia, tienen un perfil "Pro", los otros se consideran "Personal"**

# %%
#Modificamos la estructura de la tabla "vendedor"

sql = "ALTER TABLE vendedor ADD perfil VARCHAR(10);"
cursor.execute(sql)

# %%
sql = "UPDATE vendedor SET perfil=\"Personal\";"
cursor.execute(sql)
cursor.execute("COMMIT")

# %%
#Actualizamos la columna "perfil" para los vendedores que publicaron más de 5 anuncios en el último día


sql = "SELECT id_vendedor FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor HAVING count(*) >= 5 ORDER BY count(*) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
#print(df1[:5])

for index,row in df1.iterrows():
    id_vendedor=row[0]
    
    sql = "UPDATE vendedor SET perfil=\"Pro\" WHERE id_vendedor=\""+id_vendedor+"\";"
    cursor.execute(sql)

cursor.execute("COMMIT")

# %% [markdown]
# * **¿Cuál es el número de vendedores por tipo de perfil?"**

# %%
sql = "SELECT perfil, count(*) as vendedores FROM vendedor GROUP BY perfil;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#      perfil  vendedores
# 0  Personal         544
# 1       Pro          20

# %% [markdown]
# * **¿Cual es el precio promedio de los anuncios segun el dia de la semana (lunes,martes,miercoles,etc)?**

# %%
sql = "select DAYOFWEEK(fecha_publicacion) as dia,categoria, avg(precio) from anuncio where moneda=\"$\" group by dia, categoria order by avg(precio) desc;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#     dia                                  categoria    avg(precio)
# 0     6                            Vendo - Terreno  90801588.1333
# 1     6                               Vendo - Casa  89666666.6667
# 2     6                       Vendo - Departamento  82097500.0000
# 3     6                 Buses, camiones y furgones  14181290.3871
# 4     6                            Otros vehículos  11980000.0000
# 5     6             Vendo - Comercial e industrial   7500000.0000
# 6     6                    Autos, camionetas y 4x4   6220769.2308
# 7     6         Accesorios y piezas para vehículos   3136713.0000
# 8     6                                      Motos   1563636.3636
# 9     6                            Otros productos   1062207.7778
# 10    6          Arriendo - Comercial e industrial    826666.6667
# 11    6        Negocios, maquinaria y construcción    774479.0769
# 12    6                          Ofertas de empleo    584357.1429
# 13    6                    Arriendo - Departamento    346999.9750
# 14    6                            Arriendo - Casa    290246.8889
# 15    6                  Animales y sus accesorios    221250.0000
# 16    6          Celulares, teléfonos y accesorios    165600.0000
# 17    6            Deportes, gimnasia y accesorios    139800.0000
# 18    6          Bicicletas, ciclismo y accesorios    132000.0000
# 19    6  Arriendo - Estacionamiento, bodega u otro    130000.0000
# 20    6                                    Muebles    124595.9615
# 21    6                  Computadores y accesorios    116138.8889
# 22    6              Audio, TV, video y fotografía    102332.3810
# 23    6                           Arriendo - Pieza     99437.5000
# 24    6         Consolas, videojuegos y accesorios     89578.4211
# 25    6                          Electrodomésticos     86800.0000
# 26    6                                  Servicios     85315.7895
# 27    6        Instrumentos musicales y accesorios     65428.5714
# 28    6           Arte, antigüedades y colecciones     58550.0000
# 29    6                          Hobbies y outdoor     57515.3846
# 30    6          Jardín, herramientas y exteriores     43762.5000
# 31    6             Bolsos, bisutería y accesorios     42841.9355
# 32    6                                   Juguetes     41722.2222
# 33    6              Coches y artículos infantiles     32111.1111
# 34    6                                    Calzado     28374.1667
# 35    6            Música y películas (DVDs, etc.)     26181.8182
# 36    6                           Moda y vestuario     24652.3636
# 37    6                  Otros artículos del hogar     24186.8750
# 38    6                            Salud y belleza     21740.3030
# 39    6                          Libros y revistas     14977.8571
# 40    6              Vestuario futura mamá y niños     10306.4516

# %% [markdown]
# ### Pregunta 6: Implementar un script Python para visualizar la distribucion de los precios en la categoria "Arriendo - Departamento"

# %%
pd.options.display.max_colwidth = 300

sql = "select url,titulo,precio from anuncio where moneda = \"$\" and categoria = \"Arriendo - Departamento\" order by precio DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1[:20]
# Out:
#                                                                                                                                              url  \
# 0               https://www.yapo.cl/region_metropolitana/arrendar/departamento_metro_manquehue_las_condes_74027732.htm?ca=15_s&oa=74027732&xsp=9
# 1   https://www.yapo.cl/region_metropolitana/arrendar/oportunidad_depto__amoblado_a_pasos_mt_esc_militar_74027979.htm?ca=15_s&oa=74027979&xsp=11
# 2   https://www.yapo.cl/region_metropolitana/arrendar/oportunidad_depto__amoblado_a_pasos_mt_esc_militar_74027979.htm?ca=15_s&oa=74027979&xsp=44
# 3                    https://www.yapo.cl/antofagasta/arrendar/departamento__el_yodo_condominio_terramar_2_74027894.htm?ca=3_s&oa=74027894&xsp=30
# 4                    https://www.yapo.cl/antofagasta/arrendar/departamento__el_yodo_condominio_terramar_2_74027894.htm?ca=3_s&oa=74027894&xsp=48
# 5                                   https://www.yapo.cl/araucania/arrendar/hermoso_departamento_amoblado_74027986.htm?ca=10_s&oa=74027986&xsp=37


# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)

# %%
fig, ax = plt.subplots()
sns.distplot(x, kde=False, norm_hist=False)
ax.set_xlim(0,1400000)
# Out:
# (0.0, 1400000.0)

# %% [markdown]
# ### Pregunta 7: Implementar un script Python para visualizar un mapa donde se indica el precio promedio de los anuncios para cada region, por una categoria de anuncio particular

# %% [markdown]
# ### Shapefile

# %%
shp_path = "./cl_regiones_geo/cl_regiones_geo.shp"
sf = shp.Reader(shp_path, encoding="ISO8859-1")

# %%
len(sf.shapes())
# Out:
# 15

# %%
sf.records()[2]
# Out:
# Record #2: ['02', 'Antofagasta']

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (15, 3)

# %%
df.sample(15)
# Out:
#    ID_2002                                   NOMBRE  \
# 4       04                                 Coquimbo
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 11      14                                 Los Rios
# 0       15                       Arica y Parinacota
# 2       02                              Antofagasta
# 7       06      Libertador Gral. Bernardo O'Higgins
# 6       13                Metropolitana de Santiago
# 8       07                                    Maule
# 3       03                                  Atacama
# 14      12     Magallanes y de la Antartica Chileno
# 10      09                             La Araucania
# 5       05                               Valparaiso
# 12      10                                Los Lagos
# 9       08                                   Biobio
# 1       01                                 Tarapaca
#
#                                                                                                                                                                                                                                                                                                          coords
# 4   [(-69.952308, -29.503367), (-69.951567, -29.504541), (-69.949123, -29.506984), (-69.948146, -29.509428), (-69.948146, -29.51065), (-69.947168, -29.511627), (-69.946924, -29.513826), (-69.947413, -29.515048), (-69.947168, -29.519446), (-69.950101, -29.519935), (-69.951078, -29.521401), (-69.94912...
# 13  [(-72.737018, -43.829555), (-72.738551, -43.829555), (-72.740083, -43.831088), (-72.746212, -43.831088), (-72.747745, -43.83262), (-72.752342, -43.83262), (-72.753874, -43.834152), (-72.755406, -43.834152), (-72.7646, -43.829555), (-72.767665, -43.826491), (-72.77073, -43.824958), (-72.77073, -4...
# 11  [(-71.967833, -40.63312), (-71.971205, -40.634826), (-71.978243, -40.634286), (-71.984892, -40.635549), (-71.989188, -40.636873), (-71.988638, -40.635093), (-71.990974, -40.634674), (-71.993373, -40.635688), (-71.999519, -40.636246), (-72.002486, -40.639397), (-72.007092, -40.637125), (-72.00702...
# 0   [(-70.266233, -19.190222), (-70.27196, -19.188924), (-70.274566, -19.183454), (-70.277604, -19.176722), (-70.274031, -19.171294), (-70.275326, -19.16751), (-70.273523, -19.16249), (-70.27084, -19.157895), (-70.270788, -19.151185), (-70.26988, -19.147836), (-70.269848, -19.143642), (-70.279036, -...
# 1   [(-70.286169, -19.228974), (-70.130959, -19.15446), (-70.098969, -19.118882), (-70.0024, -19.080015), (-69.998215, -19.07553), (-69.982967, -19.067159), (-69.980575, -19.064468), (-69.977885, -19.063273), (-69.975194, -19.065365), (-69.963534, -19.059685), (-69.956359, -19.053406), (-69.952173, ...

# %% [markdown]
# #### Funciones utiles

# %%
def plot_regiones_data(sf, title, regiones, data=None, 
                      color=None, print_id=False):
    '''
    Plot map with selected comunes, using specific color
    '''
    
    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    region_id = []
    for i in regiones:
        #print(i)
        id = df[df.NOMBRE == i].index.get_values()[0]
        region_id.append(id)
        
        
    y_lim = (-41,-17) # latitude 
    x_lim = (-76, -66) # longitude
    
    plot_map_fill_multiples_ids_tone(sf, title, region_id, 
                                     print_id, 
                                     color_ton, 
                                     bins, 
                                     x_lim = x_lim, 
                                     y_lim = y_lim, 
                                     figsize = (10,25));

# %%
def calc_color(data, color=None):
        if color   == 1: 
            color_sq =  ['#dadaebFF','#bcbddcF0','#9e9ac8F0',
                        '#807dbaF0','#6a51a3F0','#54278fF0']; 
            colors = 'Purples';
        elif color == 2: 
            color_sq = ['#c7e9b4','#7fcdbb','#41b6c4',
                        '#1d91c0','#225ea8','#253494']; 
            colors = 'YlGnBu';
        elif color == 3: 
            color_sq = ['#f7f7f7','#d9d9d9','#bdbdbd',
                        '#969696','#636363','#252525']; 
            colors = 'Greys';
        elif color == 9: 
            color_sq = ['#ff0000','#ff0000','#ff0000',
                        '#ff0000','#ff0000','#ff0000']
        else:            
            color_sq = ['#ffffd4','#fee391','#fec44f',
                        '#fe9929','#d95f0e','#993404']; 
            colors = 'YlOrBr';
        
        new_data, bins = pd.qcut(data, 6, retbins=True, labels=list(range(6)))
        color_ton = []
        for val in new_data:
            color_ton.append(color_sq[val]) 
        if color != 9:
            colors = sns.color_palette(colors, n_colors=6)
            sns.palplot(colors, 0.6);
            for i in range(6):
                print ("\n"+str(i+1)+': '+str(int(bins[i]))+
                       " => "+str(int(bins[i+1])-1), end =" ")
            print("\n\n   1   2   3   4   5   6")    
        return color_ton, bins;

# %%
def plot_map_fill_multiples_ids_tone(sf, title, comuna,  
                                     print_id, color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (5,12)):
    '''
    Plot map with lim coordinates
    '''
        
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color_ton[comuna.index(id)])
        if print_id != False:
            x0 = np.mean(x_lon)
            y0 = np.mean(y_lat)
            plt.text(x0, y0, id, fontsize=10)
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
sql = "select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria=\"Arriendo - Departamento\" and moneda=\"$\" and nombre_region != \"Ñuble\" and precio < 1500000 group by nombre_region order by precio_prom DESC;"
print(sql)
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
# select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria="Arriendo - Departamento" and moneda="$" and nombre_region != "Ñuble" and precio < 1500000 group by nombre_region order by precio_prom DESC;
#    nombre_region  precio_prom
# 0    Antofagasta  460000.0000
# 1      Los Lagos  390000.0000
# 2  Metropolitana  377999.9500
# 3      Araucanía  350000.0000
# 4     Valparaíso  272857.1429
# 5       Coquimbo  240000.0000
# 6       Los Ríos  150000.0000

# %%
df1["precio_prom"] = df1["precio_prom"].astype(int)
df1
# Out:
#    nombre_region  precio_prom
# 0    Antofagasta       460000
# 1      Los Lagos       390000
# 2  Metropolitana       377999
# 3      Araucanía       350000
# 4     Valparaíso       272857
# 5       Coquimbo       240000
# 6       Los Ríos       150000

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
df1
# Out:
#                nombre_region  precio_prom
# 0                Antofagasta       460000
# 1                  Los Lagos       390000
# 2  Metropolitana de Santiago       377999
# 3               La Araucania       350000
# 4                 Valparaiso       272857
# 5                   Coquimbo       240000
# 6                   Los Rios       150000

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
#!pip install descartes

# %%
import geopandas as gpd
df_geo = gpd.read_file(shp_path)
df_geo
# Out:
#    ID_2002                                   NOMBRE  \
# 0       15                       Arica y Parinacota
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 3       03                                  Atacama
# 4       04                                 Coquimbo
# 5       05                               Valparaiso
# 6       13                Metropolitana de Santiago
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 12      10                                Los Lagos
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
#
#                                                                                                                                                                                                                                                                                                        geometry
# Valparaiso                 POLYGON ((-70.31980 -32.27473, -70.31443 -32.27449, -70.31320 -32.27449, -70.30710 -32.27669, -70.30294 -32.27644, -70.29805 -32.27742, -70.29488 -32.28157, -70.29341 -32.28377, -70.29390 -32.28671, -70.29121 -32.28817, -70.28779 -32.29013, -70.28584 -32.29208, -70.28193 -32.29330, -70.27582 -32...
# Metropolitana de Santiago  POLYGON ((-70.24362 -33.18739, -70.24229 -33.18418, -70.24010 -33.17989, -70.23790 -33.17489, -70.23956 -33.17165, -70.23992 -33.16699, -70.23816 -33.16342, -70.23558 -33.16129, -70.23171 -33.15918, -70.22955 -33.15705, -70.22646 -33.14955, -70.22897 -33.14630, -70.23151 -33.14448, -70.23446 -33...
# La Araucania               POLYGON ((-71.04429 -38.12317, -71.02934 -38.13412, -71.02774 -38.13919, -71.02427 -38.14479, -71.02480 -38.14933, -71.02080 -38.15066, -71.01787 -38.15040, -71.01039 -38.15333, -71.01066 -38.16081, -71.00932 -38.16267, -70.99705 -38.16934, -70.99625 -38.17175, -70.99651 -38.17682, -70.99491 -38...
# Los Rios                   POLYGON ((-71.96783 -40.63312, -71.97120 -40.63483, -71.97824 -40.63429, -71.98489 -40.63555, -71.98919 -40.63687, -71.98864 -40.63509, -71.99097 -40.63467, -71.99337 -40.63569, -71.99952 -40.63625, -72.00249 -40.63940, -72.00709 -40.63712, -72.00703 -40.63569, -72.00894 -40.63636, -72.01089 -40...
# Los Lagos                  MULTIPOLYGON (((-73.72028 -40.24713, -73.71884 -40.24775, -73.71589 -40.24572, -73.71110 -40.24412, -73.70631 -40.24253, -73.70277 -40.23873, -73.69793 -40.23642, -73.69327 -40.23660, -73.68681 -40.23794, -73.68224 -40.23956, -73.67922 -40.24327, -73.67932 -40.24470, -73.68045 -40.24752, -73.682...
#
#                            precio_prom
# Antofagasta                     460000
# Coquimbo                        240000
# Valparaiso                      272857
# Metropolitana de Santiago       377999
# La Araucania                    350000
# Los Rios                        150000
# Los Lagos                       390000

# %%
import geopandas as gpd
#df_geo = gpd.read_file(shp_path)
fig, ax = plt.subplots(figsize=(10,20))
result.plot(ax=ax,edgecolor='black',column='precio_prom', cmap='OrRd',legend=True,
        legend_kwds={'label': "Valor arriendo departamento (datos Yapo.cl)",'orientation': "horizontal"})
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# ### Pregunta 8: Implementar un script Python para mostrar las 10 palabras claves ("mas frecuentes") de cada categoria de anuncios.

# %%
#!pip install collections
#!pip install spacy
#!python -m spacy download es_core_news_sm

# %%
import spacy 
from collections import Counter
import pandas as pd
import mysql.connector
db_connection = mysql.connector.connect(user="root",host="localhost",password="spawn1997")
cursor = db_connection.cursor()
cursor.execute("use Yapo")
nlp = spacy.load("es_core_news_sm")
spacy_stopwords = spacy.lang.es.stop_words.STOP_WORDS
pd.options.display.max_colwidth = 300

# %%
#se concatena todas las descripciones por categoria con group_concat
sql = "select categoria, GROUP_CONCAT( DISTINCT descripcion ORDER BY descripcion SEPARATOR', ') as concat_description from anuncio group by categoria;"
cursor.execute(sql)
df1 = pd.DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
# Vestuario futura mamá y niños              cuero negraNiñoContactar +56999133319, de algodon de la talla 4  10   12 de niña y talla 6 de niño  poleras de la minnie talla standar  entrega a Domicilio en pudahuel norte o estacion de metro a convenir, de dama varios a elegir en optimas condiciones, de niño y niña desde la talla 8 a la 12 ro...

# %%
palabras_claves = []
for i in range(df1.index.size):
    doc = nlp(df1.iloc[i].concat_description)
    #obtendremos las palabras de doc que sean adjetivos,sustantivos y verbos
    palabras = [token.text for token in doc if token.is_stop != True and token.is_punct != True and (token.pos_ == "ADJ" or token.pos_ == "VERB" or token.pos_ == "NOUN")]
    #obtendremos la frecuencia de cada palabra
    frecuencia = Counter(palabras)
    #obtenemos las 10 mas comunes
    palabras_mas_frecuentes = frecuencia.most_common(10)
    #las agregamos al arreglo creado inicialmente
    palabras_claves += [palabras_mas_frecuentes]

# %%
#creacion del segundo dataframe con las 10 palabras_claves mas frecuentes de tipo [(palabra,frecuencia),..........]
df2 = pd.DataFrame({'categoria': df1.index, 'Palabras claves' : palabras_claves})
df2.index = df2.categoria
df2.drop(['categoria'], axis = 1, inplace = True)

# %%
df2
# Out:
#                                                                                                                                                                                                   Palabras claves
# categoria
# Accesorios y piezas para vehículos                                            [(llantas, 2), (mes, 2), (precio, 2), (par, 2), (original, 2), (discos, 1), (frenos, 1), (vehículo, 1), (marca, 1), (frelander, 1)]
# Animales y sus accesorios                                    [(mm, 8), (compartimientos, 4), (medidas, 3), (ancho, 3), (alto, 3), (separación, 3), (centro, 3), (Criadoras, 1), (canarios, 1), (inseparables, 1)]
# Arriendo - Casa                                                        [(casa, 3), (arriendo, 3), (luz, 2), (agua, 2), (comunes, 2), (incluidos, 2), (amoblada, 1), (habitaciones, 1), (incluye, 1), (gastos, 1)]
# Arriendo - Comercial e industrial                [(pleno, 2), (arrienda, 1), (propiedad, 1), (empresas, 1), (habitaciones, 1), (centroInteresados, 1), (comunicarse, 1), (numero, 1), (aviso, 1), (coordinar, 1)]
# Arriendo - Departamento                               [(detalles, 3), (diseño, 3), (principal, 3), (contemporánea, 2), (sala, 2), (dormitorios, 2), (proyecto, 2), (acceso, 2), (ufProyecto, 1), (exclusivos, 1)]
# Arriendo - Estacionamiento, bodega u otro                                  [(patio, 1), (casa, 1), (servir, 1), (ubicado, 1), (sector, 1), (norte, 1), (empezar, 1), (taller, 1), (Excelente, 1), (ubicación, 1)]
# Arriendo - Pieza                                                        [(cable, 3), (baño, 3), (agua, 3), (arrienda, 2), (compartido, 2), (pieza, 2), (precios, 2), (años, 2), (habitaciones, 1), (personas, 1)]
# Arriendo - Terreno                                                                                                          [(sitio, 1), (esquina, 1), (repullo, 1), (metros, 1), (excelente, 1), (ubicación, 1)]
# Arte, antigüedades y colecciones                                 [(centímetros, 2), (resinaViene, 2), (revista, 2), (soldado, 2), (especifico, 2), (cuadro, 1), (color, 1), (óleo, 1), (diseño, 1), (renovar, 1)]
# Audio, TV, video y fotografía                                             [(alto, 2), (micrófono, 2), (rendimiento, 2), (manejo, 2), (DMs, 2), (ruido, 2), (962690644, 1), (local, 1), (ubicado, 1), (puente, 1)]
# Autos, camionetas y 4x4                                                [(eléctricos, 2), (vidrios, 2), (auto, 2), (2006, 1), (vende, 1), (renovación, 1), (estructura, 1), (muestra, 1), (foto, 1), (topones, 1)]
# Bicicletas, ciclismo y accesorios                              [(ruedas, 3), (entrenamiento, 2), (rueda, 2), (cambios, 1), (llegar, 1), (Consultas, 1), (correo, 1), (electrónico, 1), (bicicleta, 1), (niña, 1)]
# Bolsos, bisutería y accesorios                                                       [(marca, 2), (metro, 2), (original, 1), (envíos, 1), (país, 1), (bañado, 1), (cm, 1), (colgante, 1), (mide, 1), (gramos, 1)]
# Buses, camiones y furgones                                   [(combustible, 3), (documentos, 3), (aljibes, 3), (litros, 2), (permuto, 2), (camión, 2), (camiones, 2), (plumas, 2), (día-Motor, 1), (detalles, 1)]
# Calzado                                                                    [(futbol, 2), (seguridad, 2), (mujer, 2), (ve, 2), (envio, 2), (cuero, 2), (zapatillas, 2), (botas, 1), (vaqueras, 1), (excelente, 1)]
# Celulares, teléfonos y accesorios                                 [(precio, 2), (celular, 2), (detalle, 2), (megapixeles, 2), (apertura, 2), (hacerle, 1), (llegar, 1), (abell, 1), (radios, 1), (referencia, 1)]
# Coches y artículos infantiles                          [(nocturna, 3), (color, 2), (alta, 2), (enciende, 2), (visión, 2), (dispositivos, 2), (pecho, 2), (reclinable, 1), (marca, 1), (detallesvisualización, 1)]
# Computadores y accesorios                                                               [(vendo, 3), (marca, 3), (cable, 2), (botón, 2), (pesos, 1), (pc, 1), (1650, 1), (gbEs, 1), (poderosa, 1), (conocida, 1)]
# Consolas, videojuegos y accesorios                                  [(metro, 3), (original, 3), (juego, 3), (vende, 2), (control, 2), (sellado, 2), (perfecto, 1), (juegos, 1), (controles, 1), (respectivos, 1)]
# Deportes, gimnasia y accesorios                                      [(mayorista, 2), (previo, 2), (pernos, 1), (anclaje, 1), (cascos, 1), (equitación, 1), (15000, 1), (usados, 1), (chilenas, 1), (detalle, 1)]
# Electrodomésticos                                         [(secado, 2), (perfecto, 2), (conversable, 2), (eléctrica, 2), (programas, 1), (doble, 1), (compartimento, 1), (separado, 1), (pelusas, 1), (meses, 1)]
# Hobbies y outdoor                                                          [(telescopio, 5), (lacer, 4), (trae, 4), (adaptador, 2), (puntero, 2), (vende, 1), (problemas, 1), (talla, 1), (luz, 1), (enfoque, 1)]
# Instrumentos musicales y accesorios                                        [(marca, 2), (tempo, 2), (modelo, 1), (excelente, 1), (sonido, 1), (Incluye, 1), (cable, 1), (amplificar, 1), (Precio, 1), (vende, 1)]
# Jardín, herramientas y exteriores                                     [(alto, 2), (discos, 2), (Menta, 1), (compras, 1), (cercanas, 1), (trafico, 1), (despachamos, 1), (hoja, 1), (Llamenos, 1), (atendemos, 1)]
# Juguetes                                                                  [(pizarra, 1), (doble, 1), (mesita, 1), (auto, 1), (retiro, 1), (domicilio, 1), (ubicado, 1), (cerrillos, 1), (monedas, 1), (viene, 1)]
# Vestuario futura mamá y niños                                                              [(niño, 5), (talla, 4), (vende, 4), (ropa, 3), (niña, 2), (metro, 2), (marca, 2), (etiqueta, 2), (lote, 2), (bebé, 2)]

# %% [markdown]
# ### Pregunta 9: Implementar un script Python para mostrar la palabra clave ("mas frecuente") por cada region

# %%
import spacy 
from collections import Counter
import pandas as pd
import mysql.connector
db_connection = mysql.connector.connect(user="root",host="localhost",password="spawn1997")
cursor = db_connection.cursor()
cursor.execute("use Yapo")
nlp = spacy.load("es_core_news_sm")
spacy_stopwords = spacy.lang.es.stop_words.STOP_WORDS
pd.options.display.max_colwidth = 300

# %%
sql = "select vendedor.nombre_region as region, GROUP_CONCAT( DISTINCT descripcion SEPARATOR', ' ) as concat_description from anuncio JOIN vendedor using(id_vendedor) group by vendedor.nombre_region;" 
cursor.execute(sql)
df1 = pd.DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
#dejaremos como indice del dataFrame a la columna categoria
df1.index = df1.region
df1.drop(['region'], axis='columns',inplace = True)
df1
# Out:
#                                                                                                                                                                                                                                                                                                                  concat_description
# region
# Aisén                   2 llantas de 10 apernadura 6 139.7  toyota, cocina a gas en perfecto estado.Falta perilla del horno, la cual no afecta en la funcion de este.Se vende por renovacionPrecio no conversable, comprar auto doy hasta 1000000 al tiro .ofertas serias x este medio o al whatsap.940541059.o al 964116200, on...
# Antofagasta             apitillado. Excelente estado, sin ningún detalle. Original.Se entrega a domicilio Pantalón talla S, chaqueta talla M, arrienda habitaciones a personas solas, cama de plaza 1/2, cable,wifi, baño compartido con agua caliente.cocina compartida sector norte( pasaje solon salas 8540) colegio santa em...
# Araucanía               15 programas de secado, doble secado, compartimento separado para pelusas, 6 meses de uso, con todos sus accesorios., 2 audífonos ortopédicos - terapéuticos para personas con sordera y/o adulto mayor.                 Marca Siemens. De excelente calidad y en muy buen estado. Los vendo sólo por re...
# Arica & Parinacota      centímetros de altoHand paintedMaterial de resinaViene con una revista de cada soldado en especifico, de la WWII 13 centímetros de altoHand paintedMaterial de resinaViene con una revista de cada soldado en especifico, de unicornio en 5 diseñosMedidas 150 x 150 cmEntrega a domicilio, los últimos ...
# Atacama                                                                                                                                                                                                   aire alza vidrios cierre centralizado velocidad crucero 3 corridas de asiento motor 2.7 año 2009, moto con papeles al día
# Biobío                  2006 en buen estado se vende por renovación con estructura para remorque como se muestra en la foto tiene topones pero nada que dañe su funcionamiento, 3 unidades el valor de cada uno es de 22.000 son marca HGST son de 500gb 7200rpm Nuevos sellados., 5/4/3 MM C/gorroSIN USO!Se vende por problema...
# Coquimbo                $4.000500gr $8.0001 Kg  $15.000Café Colombiano 100% arábigoDespacho gratis en la Serena y Coquimbo por sobre 1 Kg, arrienda casa en Los Aromos, Parte Alta, Coquimbo.Gastos comunes (agua, luz, internet) incluidos en el valor de arriendo.Cuenta con entrada independiente, patio trasero, living-come...
# Los Lagos               130 mil pesos para un pc en buen estado, alarma y cierre centralizado NUEVO SIN USO con todos sus accesorios, arrienda dpto. en Condominio Plaza Brintrup, el cual cuenta con :* living comedor * 2 dormitorios * 1 baño * cocina con amplia logia * dormitorio principal con gran closet* closet adicio...
# Los Ríos                +56952110821Se realizan modificacionesIncluyen pernos de anclaje, celular en buen estado sin detalles hasta 160 , puedo dar más dependiendo del celular , comunicarse al watsap +56974580257, Chaqueta Lippi de Polar Grueso térmico, Talla S, ideal para el frío. Es original, se vende por no uso (me ...
# Magallanes & Antártica  cristian lay 5000 Mascaras negras 5000 Sombra 5000 Jabon liquido 5000 Desodorante rollon 5000 Desodorante kayak sprai 6000, de niño y niña desde la talla 8 a la 12 ropa nueva 100% chilena 12.000 c/u, furgón económico andando, es para guardar mis cositas para vender en la feria, gastado el forro ...
# Maule                   a medida, cada cuadro de color que se encuentra dentro es en óleo, diseño propio.Ideal lara renovar algún espacio de tu casa. Se vende por renovación +56952070417, BLUE HDI 1.6. Un sólo dueño, mecánico, petrolero, mantenciones al día, con neumáticos cambiados hace poco, sensores y cámara de retr...
# Metropolitana           (500.gigas) en perfecto estado super bien cuidado.incluye 5 juegos dos controles y sus respectivos cables.se vende o permuta por celular.precio conversable., 10 de 10 nada que hacerle solo llegar y usar, 26 con cambios. Buen estado llegar y usar. Consultas al correo electrónico o mi WhatsApp., 2...
# Ñuble                   (Alemania, 1978). Disco excelente., (Alemania, 1978). Primera edición. Disco como nuevo., (Alemania, 1978). Primera edición. Incluye póster y número de catálogo corregido con un adhesivo. Disco excelente., (Alemania, 1982). Disco como nuevo., (Alemania, 1987). Primera edición. Incluye inserto. D...
# O'Higgins               2 discos de frenos de un vehículo marca rover frelander nuevos sin uso., 3 cuerpo y 2 sillones, arriendo urgente, vivo con mis dos hijos y necesitamos arriendo con urgencia para la próxima semana ya sea departamento o casa, buen estado, buen funcionamiento mecanico, uso familiar, tiene una triza...
# Tarapacá                (4 unidades) en excelente estado. Color café. Contacto inbox, 100% original Se hacen envíos a todo el país, cascos de equitación por 15000, usados., de 128 gb nuevo, mejora la velocidad de tu pc o notebook.Se puede dar con sistema operativo mas office mas adicional.Consultas al 997985095, galpon...
# Valparaíso              1650 de 4 gbEs mas poderosa que la gtx 1050 y que la gtx 1050tiLa vendo por renovacionSe que la marca es poco conocida pero la marca solo crea la disipacion no tiene nada que ver con el chip grafico que es igual en todas las gtx 1650Nunca supera los 65 gradosEsta tarjeta no necesita alimentación...

# %%
palabra_clave = []
for i in range(df1.index.size):
    doc = nlp(df1.iloc[i].concat_description)
    #obtendremos las palabras de doc que sean adjetivos,sustantivos y verbos
    palabras = [token.text for token in doc if token.is_stop != True and token.is_punct != True and (token.pos_ == "ADJ" or token.pos_ == "VERB" or token.pos_ == "NOUN")]
    #obtendremos la frecuencia de cada palabra
    frecuencia = Counter(palabras)
    #obtenemos las 10 mas comunes
    palabras_mas_frecuentes = frecuencia.most_common(1)
    #las agregamos al arreglo creado inicialmente
    palabra_clave += [palabras_mas_frecuentes]

# %%
#creacion del segundo dataframe con las 10 palabras_claves mas frecuentes de tipo [(palabra,frecuencia),..........]
df2 = pd.DataFrame({'region': df1.index, 'Palabra clave' : palabra_clave})
df2.index = df2.region
df2.drop(['region'], axis = 1, inplace = True)

# %%
df2
# Out:
#                              Palabra clave
# region
# Aisén                       [(llantas, 1)]
# Antofagasta                    [(baño, 3)]
# Araucanía                    [(secado, 2)]
# Arica & Parinacota      [(centímetros, 2)]
# Atacama                        [(alza, 1)]
# Biobío                        [(vende, 2)]
# Coquimbo                   [(arrienda, 1)]
# Los Lagos                     [(pesos, 1)]
# Los Ríos                    [(celular, 2)]
# Magallanes & Antártica         [(5000, 2)]
# Maule                         [(litro, 2)]
# Metropolitana                [(llegar, 2)]
# Ñuble                         [(Disco, 4)]
# O'Higgins               [(conversable, 3)]
# Tarapacá                   [(original, 2)]
# Valparaíso                    [(vendo, 2)]

# %% [markdown]
# ### Pregunta 10: A partir de los datos disponibles en Yapo.cl, ¿que escenario de analisis pueden proponer para analizar la actividad economica en Chile durante el periodo de covid?

# %% [markdown]
# lo primero que se me habia ocurrido era analizar los tipos de anuncios que se creaban antes del covid y compararlos con los actuales. pero lamentablemente la pagina "YAPO" no tiene un opcion para filtrar por fecha. por lo que se realizara un analisis con los datos obtenidos en el scraping anterior, donde se mostraran la cantidad de anuncios por categoria ademas de una visualizacion grafica

# %%
import mysql.connector
db_connection = mysql.connector.connect(user="root",host="localhost",password="spawn1997")
cursor = db_connection.cursor()
cursor.execute("use Yapo")

# %%
sql = "select categoria, count(*) as num_anuncios from anuncio group by categoria;"
cursor.execute(sql)
df1 = pd.DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                     categoria  num_anuncios
# 0          Accesorios y piezas para vehículos            53
# 1                   Animales y sus accesorios             8
# 2                             Arriendo - Casa             9
# 3           Arriendo - Comercial e industrial             3
# 4                     Arriendo - Departamento            43
# 5   Arriendo - Estacionamiento, bodega u otro             3
# 6                            Arriendo - Pieza             8
# 7                          Arriendo - Terreno             1
# 8            Arte, antigüedades y colecciones            16
# 9               Audio, TV, video y fotografía            42
# 10                    Autos, camionetas y 4x4           104
# 11          Bicicletas, ciclismo y accesorios             8
# 12             Bolsos, bisutería y accesorios            31
# 13                 Buses, camiones y furgones            31
# 14                                    Calzado            24
# 15          Celulares, teléfonos y accesorios            35
# 16              Coches y artículos infantiles            18
# 17                  Computadores y accesorios            36
# 18         Consolas, videojuegos y accesorios            19
# 19            Deportes, gimnasia y accesorios            10
# 20                          Electrodomésticos            25
# 21                          Hobbies y outdoor            13
# 22        Instrumentos musicales y accesorios            14
# 23          Jardín, herramientas y exteriores            16
# 24                                   Juguetes             9
# 25                          Libros y revistas            28
# 26                           Moda y vestuario            55
# 27                                      Motos            11
# 28                                    Muebles            52
# 29            Música y películas (DVDs, etc.)            22
# 30        Negocios, maquinaria y construcción            26
# 31                          Ofertas de empleo            14
# 32                  Otros artículos del hogar            32
# 33                            Otros productos             9
# 34                            Otros vehículos             8
# 35                            Salud y belleza            33
# 36                                  Servicios            19
# 37                               Vendo - Casa            14
# 38             Vendo - Comercial e industrial             2
# 39                       Vendo - Departamento            12
# 40                            Vendo - Terreno            17
# 41              Vestuario futura mamá y niños            31

# %% [markdown]
# select vendedor.nombre_region as region, GROUP_CONCAT( DISTINCT descripcion SEPARATOR', ' ) as concat_description from anuncio JOIN vendedor using(id_vendedor) group by vendedor.nombre_region;
